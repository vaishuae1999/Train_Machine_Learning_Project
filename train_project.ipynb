# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishuae1999/Train_Machine_Learning_Project/blob/main/train_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- Step 1: Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- Step 2: Create project folder structure ---
import os

base_dir = "/content/drive/MyDrive/train_project"
raw_video_dir = os.path.join(base_dir, "Raw_video", "DHN-wagon")
processed_video_dir = os.path.join(base_dir, "Processed_Video")

# Create folders if they don’t exist
os.makedirs(raw_video_dir, exist_ok=True)
os.makedirs(processed_video_dir, exist_ok=True)

print("✅ Folders created:")
print("Raw video path:", raw_video_dir)
print("Processed video path:", processed_video_dir)

# --- Step 3: Install dependencies ---
# !pip install opencv-python moviepy numpy tqdm ultralytics reportlab

# --- Step 4: Verify installation ---
import cv2, moviepy, numpy, tqdm, ultralytics, reportlab
print("✅ All libraries imported successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Folders created:
# Raw video path: /content/drive/MyDrive/train_project/Raw_video/DHN-wagon
# Processed video path: /content/drive/MyDrive/train_project/Processed_Video
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.191)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.12/dist-packages (4.4.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.12/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.16)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab) (3.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# ✅ All libraries imported successfully!

# %%
# ==========================
# INSTALL DEPENDENCIES
# ==========================
# !pip install ultralytics reportlab opencv-python-headless

import cv2, os, glob, shutil, numpy as np
from ultralytics import YOLO
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Image, PageBreak
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import A4
from matplotlib import pyplot as plt

# ==========================
# PATHS
# ==========================
input_folder  = "/content/drive/MyDrive/train_project/Raw_video/DHN-wagon"   # raw videos
work_root     = "/content/drive/MyDrive/train_project/Processed"             # all outputs
frames_root   = os.path.join(work_root, "Frames")
coach_video_root = os.path.join(work_root, "Coach_Videos")
coach_frames_root = os.path.join(work_root, "Coach_Frames")
report_frames_root = os.path.join(work_root, "Report_Frames")
report_root   = os.path.join(work_root, "Reports")

for p in [frames_root, coach_video_root, coach_frames_root, report_frames_root, report_root]:
    os.makedirs(p, exist_ok=True)

# ==========================
# LOAD YOLO MODEL
# ==========================
# Replace 'yolov8n.pt' with your custom-trained model for doors
model = YOLO('yolov8n.pt')

# ==========================
# HELPER: DETECT COACH BOUNDARIES
# ==========================
def detect_coach_boundaries(frame, expected_width=None):
    """Return list of vertical boundary positions for coaches"""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    edges = cv2.Canny(gray, 50, 150)

    # strengthen vertical edges
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,25))
    edges = cv2.dilate(edges, kernel, iterations=1)

    # vertical projection
    vertical_projection = np.sum(edges, axis=0)
    vp_sm = np.convolve(vertical_projection, np.ones(31)/31, mode='same')

    threshold = vp_sm.max() * 0.25
    boundaries = [i for i,v in enumerate(vp_sm) if v > threshold]

    # group close lines
    clean = []
    for b in boundaries:
        if not clean or b - clean[-1] > 50:
            clean.append(b)

    if expected_width and clean[-1] != expected_width:
        clean.append(expected_width)
    if clean[0] != 0:
        clean = [0] + clean
    return clean

# ==========================
# STEP 1+2: READ VIDEOS & SAVE FRAMES
# ==========================
video_files = glob.glob(os.path.join(input_folder, "*.mp4"))
print(f"Found {len(video_files)} videos.")

for video_path in video_files:
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    video_frame_dir = os.path.join(frames_root, video_name)
    os.makedirs(video_frame_dir, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    frame_no, saved = 0, 0
    sample_frame = None
    while True:
        ret, frame = cap.read()
        if not ret: break
        if frame_no % 10 == 0:
            out_path = os.path.join(video_frame_dir, f"{video_name}_frame_{frame_no}.jpg")
            cv2.imwrite(out_path, frame)
            saved += 1
            if sample_frame is None: sample_frame = frame
        frame_no += 1
    cap.release()
    print(f"Extracted {saved} frames from {video_name}")

    # ==========================
    # STEP 3: DETECT COACHES
    # ==========================
    boundaries = detect_coach_boundaries(sample_frame, expected_width=width)
    coach_count = len(boundaries)-1
    print(f"Detected {coach_count} coaches in {video_name}")

    # ==========================
    # STEP 4: SPLIT INTO COACH VIDEOS
    # ==========================
    cap = cv2.VideoCapture(video_path)
    writers = []
    coach_dir = os.path.join(coach_video_root, video_name)
    os.makedirs(coach_dir, exist_ok=True)

    for i in range(len(boundaries)-1):
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out_file = os.path.join(coach_dir, f"{video_name}_{i+1}.mp4")
        writer = cv2.VideoWriter(out_file, fourcc, fps, (boundaries[i+1]-boundaries[i], height))
        writers.append(writer)

    while True:
        ret, frame = cap.read()
        if not ret: break
        for i in range(len(boundaries)-1):
            crop = frame[:, boundaries[i]:boundaries[i+1]]
            writers[i].write(crop)
    cap.release()
    for w in writers: w.release()
    print(f"Saved {coach_count} coach videos for {video_name}")

    # ==========================
    # STEP 5: EXTRACT FRAMES PER COACH
    # ==========================
    for i in range(len(boundaries)-1):
        coach_video = os.path.join(coach_dir, f"{video_name}_{i+1}.mp4")
        coach_frame_dir = os.path.join(coach_frames_root, f"{video_name}_{i+1}")
        os.makedirs(coach_frame_dir, exist_ok=True)

        cap = cv2.VideoCapture(coach_video)
        frame_no, saved = 0, 0
        while True:
            ret, frame = cap.read()
            if not ret: break
            if frame_no % 10 == 0:
                out_path = os.path.join(coach_frame_dir, f"{video_name}_{i+1}_frame_{frame_no}.jpg")
                cv2.imwrite(out_path, frame)
                saved += 1
            frame_no += 1
        cap.release()
        print(f"Extracted {saved} frames for coach {i+1}")

        # ==========================
        # STEP 6: DOOR DETECTION
        # ==========================
        frames = sorted(glob.glob(os.path.join(coach_frame_dir, "*.jpg")))
        for f in frames:
            results = model(f, conf=0.3)
            results[0].save(filename=f.replace(".jpg","_det.jpg"))

        # ==========================
        # STEP 7: MINIMAL IMAGES (FRONT/MID/REAR)
        # ==========================
        if frames:
            sel = [frames[0], frames[len(frames)//2], frames[-1]]
            report_dir = os.path.join(report_frames_root, f"{video_name}_{i+1}")
            os.makedirs(report_dir, exist_ok=True)
            for sf in sel:
                shutil.copy(sf, os.path.join(report_dir, os.path.basename(sf)))

# ==========================
# STEP 8: GENERATE REPORTS
# ==========================
styles = getSampleStyleSheet()

train_ids = {}
coach_dirs = sorted(glob.glob(os.path.join(report_frames_root, "*")))
for cd in coach_dirs:
    cname = os.path.basename(cd)        # train1_1
    tid = cname.split("_")[0]           # train1
    train_ids.setdefault(tid, []).append(cd)

for tid, coach_dirs in train_ids.items():
    report_path = os.path.join(report_root, f"{tid}_report.pdf")
    doc = SimpleDocTemplate(report_path, pagesize=A4)
    story = []

    story.append(Paragraph(f"Train Report: {tid}", styles['Title']))
    story.append(Spacer(1,20))
    story.append(Paragraph(f"Total Coaches: {len(coach_dirs)}", styles['Heading2']))
    story.append(PageBreak())

    for cd in sorted(coach_dirs):
        cname = os.path.basename(cd)
        story.append(Paragraph(f"Coach {cname}", styles['Heading2']))
        story.append(Spacer(1,10))

        imgs = sorted(glob.glob(os.path.join(cd,"*.jpg")))
        for im in imgs:
            try:
                story.append(Image(im, width=200, height=120))
                story.append(Spacer(1,10))
            except: pass
        story.append(PageBreak())

    doc.build(story)
    print(f"✅ Report saved: {report_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1930.jpg: 640x64 (no detections), 92.6ms
# Speed: 0.8ms preprocess, 92.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1940.jpg: 640x64 (no detections), 67.9ms
# Speed: 0.8ms preprocess, 67.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1950.jpg: 640x64 (no detections), 105.0ms
# Speed: 0.8ms preprocess, 105.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1960.jpg: 640x64 (no detections), 72.3ms
# Speed: 0.8ms preprocess, 72.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1970.jpg: 640x64 (no detections), 77.8ms
# Speed: 0.9ms preprocess, 77.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1980.jpg: 640x64 (no detections), 70.0ms
# Speed: 0.8ms preprocess, 70.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_1990.jpg: 640x64 (no detections), 91.0ms
# Speed: 0.8ms preprocess, 91.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_20.jpg: 640x64 (no detections), 70.0ms
# Speed: 0.8ms preprocess, 70.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_200.jpg: 640x64 (no detections), 166.7ms
# Speed: 0.9ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2000.jpg: 640x64 (no detections), 127.4ms
# Speed: 0.9ms preprocess, 127.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2010.jpg: 640x64 (no detections), 85.5ms
# Speed: 0.8ms preprocess, 85.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2020.jpg: 640x64 (no detections), 75.2ms
# Speed: 0.8ms preprocess, 75.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2030.jpg: 640x64 (no detections), 77.2ms
# Speed: 0.9ms preprocess, 77.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2040.jpg: 640x64 (no detections), 95.1ms
# Speed: 0.9ms preprocess, 95.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2050.jpg: 640x64 (no detections), 85.9ms
# Speed: 0.9ms preprocess, 85.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2060.jpg: 640x64 (no detections), 75.1ms
# Speed: 0.9ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2070.jpg: 640x64 (no detections), 97.9ms
# Speed: 0.9ms preprocess, 97.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2080.jpg: 640x64 (no detections), 100.0ms
# Speed: 0.9ms preprocess, 100.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2090.jpg: 640x64 (no detections), 81.2ms
# Speed: 0.9ms preprocess, 81.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_210.jpg: 640x64 (no detections), 75.4ms
# Speed: 0.8ms preprocess, 75.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2100.jpg: 640x64 (no detections), 98.2ms
# Speed: 0.9ms preprocess, 98.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2110.jpg: 640x64 (no detections), 72.6ms
# Speed: 0.9ms preprocess, 72.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2120.jpg: 640x64 (no detections), 82.2ms
# Speed: 1.0ms preprocess, 82.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2130.jpg: 640x64 (no detections), 73.7ms
# Speed: 0.8ms preprocess, 73.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2140.jpg: 640x64 (no detections), 69.5ms
# Speed: 1.1ms preprocess, 69.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2150.jpg: 640x64 (no detections), 70.4ms
# Speed: 0.8ms preprocess, 70.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2160.jpg: 640x64 (no detections), 94.3ms
# Speed: 0.8ms preprocess, 94.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2170.jpg: 640x64 (no detections), 76.7ms
# Speed: 0.9ms preprocess, 76.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2180.jpg: 640x64 (no detections), 69.7ms
# Speed: 0.8ms preprocess, 69.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2190.jpg: 640x64 (no detections), 68.1ms
# Speed: 0.8ms preprocess, 68.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_220.jpg: 640x64 (no detections), 68.7ms
# Speed: 1.1ms preprocess, 68.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_2200.jpg: 640x64 (no detections), 68.6ms
# Speed: 0.9ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_230.jpg: 640x64 (no detections), 79.0ms
# Speed: 0.8ms preprocess, 79.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_240.jpg: 640x64 (no detections), 92.8ms
# Speed: 0.9ms preprocess, 92.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_250.jpg: 640x64 (no detections), 80.5ms
# Speed: 0.9ms preprocess, 80.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_260.jpg: 640x64 (no detections), 74.1ms
# Speed: 0.8ms preprocess, 74.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_270.jpg: 640x64 (no detections), 73.6ms
# Speed: 0.8ms preprocess, 73.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_280.jpg: 640x64 (no detections), 93.6ms
# Speed: 0.9ms preprocess, 93.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_290.jpg: 640x64 (no detections), 97.8ms
# Speed: 0.9ms preprocess, 97.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_30.jpg: 640x64 (no detections), 87.9ms
# Speed: 1.3ms preprocess, 87.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_300.jpg: 640x64 (no detections), 81.3ms
# Speed: 1.0ms preprocess, 81.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_310.jpg: 640x64 (no detections), 80.6ms
# Speed: 0.8ms preprocess, 80.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_320.jpg: 640x64 (no detections), 115.0ms
# Speed: 0.9ms preprocess, 115.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_330.jpg: 640x64 (no detections), 83.6ms
# Speed: 0.8ms preprocess, 83.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_340.jpg: 640x64 (no detections), 81.3ms
# Speed: 0.9ms preprocess, 81.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_350.jpg: 640x64 (no detections), 73.4ms
# Speed: 0.8ms preprocess, 73.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_360.jpg: 640x64 (no detections), 80.7ms
# Speed: 1.2ms preprocess, 80.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_370.jpg: 640x64 (no detections), 77.7ms
# Speed: 0.8ms preprocess, 77.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_380.jpg: 640x64 (no detections), 86.2ms
# Speed: 0.9ms preprocess, 86.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_390.jpg: 640x64 (no detections), 89.4ms
# Speed: 0.8ms preprocess, 89.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_40.jpg: 640x64 (no detections), 84.4ms
# Speed: 5.0ms preprocess, 84.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_400.jpg: 640x64 (no detections), 85.2ms
# Speed: 0.9ms preprocess, 85.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_410.jpg: 640x64 (no detections), 71.9ms
# Speed: 0.9ms preprocess, 71.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_420.jpg: 640x64 (no detections), 76.0ms
# Speed: 0.8ms preprocess, 76.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_430.jpg: 640x64 (no detections), 66.4ms
# Speed: 0.8ms preprocess, 66.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_440.jpg: 640x64 (no detections), 56.2ms
# Speed: 0.6ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_450.jpg: 640x64 (no detections), 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_460.jpg: 640x64 (no detections), 50.3ms
# Speed: 1.0ms preprocess, 50.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_470.jpg: 640x64 (no detections), 52.6ms
# Speed: 0.9ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_480.jpg: 640x64 (no detections), 71.4ms
# Speed: 0.9ms preprocess, 71.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_490.jpg: 640x64 (no detections), 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_50.jpg: 640x64 (no detections), 66.7ms
# Speed: 0.9ms preprocess, 66.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_500.jpg: 640x64 (no detections), 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_510.jpg: 640x64 (no detections), 52.6ms
# Speed: 0.9ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_520.jpg: 640x64 (no detections), 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_530.jpg: 640x64 (no detections), 51.3ms
# Speed: 0.8ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_540.jpg: 640x64 (no detections), 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_550.jpg: 640x64 (no detections), 70.9ms
# Speed: 0.9ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_560.jpg: 640x64 (no detections), 58.4ms
# Speed: 1.1ms preprocess, 58.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_570.jpg: 640x64 (no detections), 55.6ms
# Speed: 1.1ms preprocess, 55.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_580.jpg: 640x64 (no detections), 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_590.jpg: 640x64 (no detections), 52.6ms
# Speed: 0.9ms preprocess, 52.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_60.jpg: 640x64 (no detections), 71.2ms
# Speed: 0.8ms preprocess, 71.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_600.jpg: 640x64 (no detections), 68.2ms
# Speed: 0.9ms preprocess, 68.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_610.jpg: 640x64 (no detections), 51.3ms
# Speed: 0.8ms preprocess, 51.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_620.jpg: 640x64 (no detections), 54.6ms
# Speed: 0.9ms preprocess, 54.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_630.jpg: 640x64 (no detections), 75.8ms
# Speed: 0.9ms preprocess, 75.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_640.jpg: 640x64 (no detections), 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_650.jpg: 640x64 (no detections), 46.7ms
# Speed: 0.9ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_660.jpg: 640x64 (no detections), 69.5ms
# Speed: 1.1ms preprocess, 69.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_670.jpg: 640x64 (no detections), 59.4ms
# Speed: 0.8ms preprocess, 59.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_680.jpg: 640x64 (no detections), 53.5ms
# Speed: 0.9ms preprocess, 53.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_690.jpg: 640x64 (no detections), 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_70.jpg: 640x64 (no detections), 49.6ms
# Speed: 0.9ms preprocess, 49.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_700.jpg: 640x64 (no detections), 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_710.jpg: 640x64 (no detections), 48.5ms
# Speed: 0.9ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_720.jpg: 640x64 (no detections), 72.3ms
# Speed: 0.8ms preprocess, 72.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_730.jpg: 640x64 (no detections), 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_740.jpg: 640x64 (no detections), 52.2ms
# Speed: 1.5ms preprocess, 52.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_750.jpg: 640x64 (no detections), 49.1ms
# Speed: 0.8ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_760.jpg: 640x64 (no detections), 50.4ms
# Speed: 0.8ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_770.jpg: 640x64 (no detections), 47.6ms
# Speed: 0.8ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_780.jpg: 640x64 (no detections), 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_790.jpg: 640x64 (no detections), 71.7ms
# Speed: 0.9ms preprocess, 71.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_80.jpg: 640x64 (no detections), 50.6ms
# Speed: 0.8ms preprocess, 50.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_800.jpg: 640x64 (no detections), 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_810.jpg: 640x64 (no detections), 61.0ms
# Speed: 0.9ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_820.jpg: 640x64 (no detections), 58.1ms
# Speed: 0.8ms preprocess, 58.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_830.jpg: 640x64 (no detections), 51.5ms
# Speed: 0.9ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_840.jpg: 640x64 (no detections), 96.0ms
# Speed: 1.0ms preprocess, 96.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_850.jpg: 640x64 (no detections), 49.4ms
# Speed: 0.8ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_860.jpg: 640x64 (no detections), 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_870.jpg: 640x64 (no detections), 50.1ms
# Speed: 0.8ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_880.jpg: 640x64 (no detections), 54.3ms
# Speed: 0.8ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_890.jpg: 640x64 (no detections), 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_90.jpg: 640x64 (no detections), 69.4ms
# Speed: 1.0ms preprocess, 69.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_900.jpg: 640x64 (no detections), 58.2ms
# Speed: 1.0ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_910.jpg: 640x64 (no detections), 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_920.jpg: 640x64 (no detections), 48.7ms
# Speed: 0.9ms preprocess, 48.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_930.jpg: 640x64 (no detections), 67.2ms
# Speed: 0.8ms preprocess, 67.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_940.jpg: 640x64 (no detections), 51.5ms
# Speed: 0.9ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_950.jpg: 640x64 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_960.jpg: 640x64 (no detections), 56.2ms
# Speed: 1.0ms preprocess, 56.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_970.jpg: 640x64 (no detections), 52.3ms
# Speed: 1.5ms preprocess, 52.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_980.jpg: 640x64 (no detections), 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_25/DHN-upper-side-view-2025-08-31-11-28-15-377_25_frame_990.jpg: 640x64 (no detections), 44.0ms
# Speed: 0.8ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
# Extracted 221 frames for coach 26
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_0.jpg: 640x64 (no detections), 52.0ms
# Speed: 0.6ms preprocess, 52.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_10.jpg: 640x64 (no detections), 74.4ms
# Speed: 0.8ms preprocess, 74.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_100.jpg: 640x64 (no detections), 130.8ms
# Speed: 0.8ms preprocess, 130.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1000.jpg: 640x64 (no detections), 45.0ms
# Speed: 0.9ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1010.jpg: 640x64 (no detections), 51.9ms
# Speed: 0.8ms preprocess, 51.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1020.jpg: 640x64 (no detections), 51.7ms
# Speed: 0.8ms preprocess, 51.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1030.jpg: 640x64 (no detections), 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1040.jpg: 640x64 (no detections), 48.0ms
# Speed: 1.0ms preprocess, 48.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1050.jpg: 640x64 (no detections), 95.4ms
# Speed: 1.0ms preprocess, 95.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1060.jpg: 640x64 (no detections), 72.8ms
# Speed: 1.1ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1070.jpg: 640x64 (no detections), 66.9ms
# Speed: 1.0ms preprocess, 66.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1080.jpg: 640x64 (no detections), 85.8ms
# Speed: 0.9ms preprocess, 85.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1090.jpg: 640x64 (no detections), 70.5ms
# Speed: 0.9ms preprocess, 70.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_110.jpg: 640x64 (no detections), 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1100.jpg: 640x64 (no detections), 86.4ms
# Speed: 1.0ms preprocess, 86.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1110.jpg: 640x64 (no detections), 116.1ms
# Speed: 0.9ms preprocess, 116.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1120.jpg: 640x64 (no detections), 83.1ms
# Speed: 0.9ms preprocess, 83.1ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1130.jpg: 640x64 (no detections), 166.1ms
# Speed: 0.9ms preprocess, 166.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1140.jpg: 640x64 (no detections), 120.3ms
# Speed: 0.8ms preprocess, 120.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1150.jpg: 640x64 (no detections), 67.8ms
# Speed: 0.9ms preprocess, 67.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1160.jpg: 640x64 (no detections), 71.7ms
# Speed: 0.8ms preprocess, 71.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1170.jpg: 640x64 (no detections), 79.5ms
# Speed: 0.8ms preprocess, 79.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1180.jpg: 640x64 (no detections), 67.6ms
# Speed: 1.0ms preprocess, 67.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1190.jpg: 640x64 (no detections), 72.8ms
# Speed: 0.9ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_120.jpg: 640x64 (no detections), 67.0ms
# Speed: 0.8ms preprocess, 67.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1200.jpg: 640x64 (no detections), 74.5ms
# Speed: 0.8ms preprocess, 74.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1210.jpg: 640x64 (no detections), 78.4ms
# Speed: 0.8ms preprocess, 78.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1220.jpg: 640x64 (no detections), 107.6ms
# Speed: 0.8ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1230.jpg: 640x64 (no detections), 107.4ms
# Speed: 0.9ms preprocess, 107.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1240.jpg: 640x64 (no detections), 85.2ms
# Speed: 0.9ms preprocess, 85.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1250.jpg: 640x64 (no detections), 93.5ms
# Speed: 0.8ms preprocess, 93.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1260.jpg: 640x64 (no detections), 73.1ms
# Speed: 0.9ms preprocess, 73.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1270.jpg: 640x64 (no detections), 82.1ms
# Speed: 0.8ms preprocess, 82.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1280.jpg: 640x64 (no detections), 75.9ms
# Speed: 0.8ms preprocess, 75.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1290.jpg: 640x64 (no detections), 84.0ms
# Speed: 0.9ms preprocess, 84.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_130.jpg: 640x64 (no detections), 107.1ms
# Speed: 0.9ms preprocess, 107.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1300.jpg: 640x64 (no detections), 87.5ms
# Speed: 0.9ms preprocess, 87.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1310.jpg: 640x64 (no detections), 78.3ms
# Speed: 0.9ms preprocess, 78.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1320.jpg: 640x64 (no detections), 96.5ms
# Speed: 0.8ms preprocess, 96.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 64)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_26/DHN-upper-side-view-2025-08-31-11-28-15-377_26_frame_1330.jpg: 640x64 (no detections), 88.8ms
# ...
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_540.jpg: 640x192 (no detections), 127.5ms
# Speed: 2.0ms preprocess, 127.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_550.jpg: 640x192 (no detections), 129.1ms
# Speed: 2.1ms preprocess, 129.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_560.jpg: 640x192 (no detections), 142.3ms
# Speed: 4.1ms preprocess, 142.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_570.jpg: 640x192 (no detections), 125.8ms
# Speed: 2.0ms preprocess, 125.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_580.jpg: 640x192 (no detections), 160.0ms
# Speed: 2.6ms preprocess, 160.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_590.jpg: 640x192 (no detections), 138.0ms
# Speed: 2.0ms preprocess, 138.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_60.jpg: 640x192 (no detections), 136.5ms
# Speed: 1.9ms preprocess, 136.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_600.jpg: 640x192 (no detections), 128.8ms
# Speed: 5.6ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_610.jpg: 640x192 (no detections), 167.0ms
# Speed: 1.8ms preprocess, 167.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_620.jpg: 640x192 (no detections), 150.9ms
# Speed: 2.0ms preprocess, 150.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_630.jpg: 640x192 (no detections), 131.3ms
# Speed: 2.2ms preprocess, 131.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_640.jpg: 640x192 (no detections), 183.7ms
# Speed: 1.8ms preprocess, 183.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_650.jpg: 640x192 (no detections), 138.3ms
# Speed: 2.1ms preprocess, 138.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_660.jpg: 640x192 (no detections), 121.9ms
# Speed: 1.8ms preprocess, 121.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_670.jpg: 640x192 (no detections), 134.7ms
# Speed: 2.2ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_680.jpg: 640x192 (no detections), 151.6ms
# Speed: 1.9ms preprocess, 151.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_690.jpg: 640x192 (no detections), 140.8ms
# Speed: 3.3ms preprocess, 140.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_70.jpg: 640x192 (no detections), 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_700.jpg: 640x192 (no detections), 162.5ms
# Speed: 1.8ms preprocess, 162.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_710.jpg: 640x192 (no detections), 137.5ms
# Speed: 1.9ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_720.jpg: 640x192 (no detections), 157.3ms
# Speed: 1.8ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_730.jpg: 640x192 (no detections), 130.1ms
# Speed: 2.0ms preprocess, 130.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_740.jpg: 640x192 (no detections), 84.2ms
# Speed: 1.8ms preprocess, 84.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_750.jpg: 640x192 (no detections), 82.1ms
# Speed: 2.5ms preprocess, 82.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_760.jpg: 640x192 (no detections), 80.5ms
# Speed: 1.8ms preprocess, 80.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_770.jpg: 640x192 (no detections), 109.8ms
# Speed: 2.2ms preprocess, 109.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_780.jpg: 640x192 (no detections), 83.7ms
# Speed: 1.9ms preprocess, 83.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_790.jpg: 640x192 (no detections), 85.7ms
# Speed: 1.8ms preprocess, 85.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_80.jpg: 640x192 (no detections), 91.9ms
# Speed: 1.9ms preprocess, 91.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_800.jpg: 640x192 (no detections), 108.9ms
# Speed: 2.3ms preprocess, 108.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_810.jpg: 640x192 (no detections), 101.1ms
# Speed: 1.9ms preprocess, 101.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_820.jpg: 640x192 (no detections), 79.7ms
# Speed: 1.9ms preprocess, 79.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_830.jpg: 640x192 (no detections), 84.1ms
# Speed: 1.9ms preprocess, 84.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_840.jpg: 640x192 (no detections), 110.2ms
# Speed: 2.7ms preprocess, 110.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_850.jpg: 640x192 (no detections), 92.0ms
# Speed: 2.2ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_860.jpg: 640x192 (no detections), 93.1ms
# Speed: 2.3ms preprocess, 93.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_870.jpg: 640x192 (no detections), 81.6ms
# Speed: 1.9ms preprocess, 81.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_880.jpg: 640x192 (no detections), 123.8ms
# Speed: 1.9ms preprocess, 123.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_890.jpg: 640x192 (no detections), 115.4ms
# Speed: 2.2ms preprocess, 115.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_90.jpg: 640x192 (no detections), 84.5ms
# Speed: 1.9ms preprocess, 84.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_900.jpg: 640x192 (no detections), 96.1ms
# Speed: 2.0ms preprocess, 96.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_910.jpg: 640x192 (no detections), 128.6ms
# Speed: 1.9ms preprocess, 128.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_920.jpg: 640x192 (no detections), 88.8ms
# Speed: 1.9ms preprocess, 88.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_930.jpg: 640x192 (no detections), 119.0ms
# Speed: 1.9ms preprocess, 119.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_940.jpg: 640x192 (no detections), 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_950.jpg: 640x192 (no detections), 88.6ms
# Speed: 1.9ms preprocess, 88.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_960.jpg: 640x192 (no detections), 83.1ms
# Speed: 1.8ms preprocess, 83.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_970.jpg: 640x192 (no detections), 87.8ms
# Speed: 2.0ms preprocess, 87.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_980.jpg: 640x192 (no detections), 88.7ms
# Speed: 1.9ms preprocess, 88.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
#
# image 1/1 /content/drive/MyDrive/train_project/Processed/Coach_Frames/DHN-upper-side-view-2025-08-31-11-28-15-377_32/DHN-upper-side-view-2025-08-31-11-28-15-377_32_frame_990.jpg: 640x192 (no detections), 109.1ms
# Speed: 1.8ms preprocess, 109.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 192)
# ✅ Report saved: /content/drive/MyDrive/train_project/Processed/Reports/DHN-side-view-lower-2025-08-31-11-24-27-47_report.pdf
# ✅ Report saved: /content/drive/MyDrive/train_project/Processed/Reports/DHN-upper-side-view-2025-08-31-11-28-15-377_report.pdf
# ✅ Report saved: /content/drive/MyDrive/train_project/Processed/Reports/DHN_report.pdf
# ✅ Report saved: /content/drive/MyDrive/train_project/Processed/Reports/Dhn-upper-side-view-2025-08-31-11-32-23-16_report.pdf
